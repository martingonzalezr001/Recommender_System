# %%
import pandas as pd

# %%
url_frontend = "../data/frontend.csv"
url_backend = "../data/backend.csv"
url_database = "../data/database.csv"
url_auth = "../data/auth-prueba.csv"
url_ecommerce = "../data/ecommerce.csv" 
url_cloudhosting = "../data/cloud-hosting.csv"
url_devops_cicd = "../data/DevOps_CICD.csv"
url_message = "../data/message.csv"
url_search_engine = "../data/search_engine.csv"
url_media_storage = "../data/media&storage.csv"

# %%
df_frontend = pd.read_csv(url_frontend, sep=",")
df_backend = pd.read_csv(url_backend, sep=",")
df_database = pd.read_csv(url_database, sep=",")
df_auth = pd.read_csv(url_auth, sep=",")
df_ecommerce = pd.read_csv(url_ecommerce, sep=",")
df_cloudhosting = pd.read_csv(url_cloudhosting, sep=",")
df_cdci_devops = pd.read_csv(url_devops_cicd, sep=",")
df_message = pd.read_csv(url_message, sep=";")
df_search_engine = pd.read_csv(url_search_engine, sep=";")
df_media_storage = pd.read_csv(url_media_storage, sep=",")

# %%
df_frontend.head(25)
# Out:
#         Producto Escalabilidad     Coste Seguridad Nivel de uso  \
# 0          React          Alta    Gratis      Alta     Muy Alto
# 1         Vue.js         Media    Gratis      Alta         Alto
# 2        Angular          Alta    Gratis  Muy Alta         Alto
# 3         Svelte         Media    Gratis      Alta        Medio
# 4        Next.js          Alta  Freemium  Muy Alta         Alto
# 5        Nuxt.js          Alta  Freemium  Muy Alta        Medio
# 6         Gatsby         Media    Gratis      Alta        Medio
# 7           Hugo          Alta    Gratis  Muy Alta         Bajo
# 8          Astro          Alta    Gratis      Alta        Medio
# 9       Ember.js          Alta    Gratis      Alta         Bajo
# 10     Alpine.js         Media    Gratis      Alta         Bajo
# 11       Stencil          Alta    Gratis      Alta         Bajo
# 12        Preact          Alta    Gratis      Alta        Medio
# 13           Lit          Alta    Gratis      Alta         Bajo
# ...

# %%
print(df_frontend.columns)
# Out:
# Index(['Producto', 'Escalabilidad', 'Coste', 'Seguridad', 'Nivel de uso',
#        'Tipo', 'Lenguaje base', 'Uso principal', 'Dificultad inicial',
#        'Crecimiento de complejidad', 'SEO Friendly'],
#       dtype='object')

# %%
df_backend.head(25)
# Out:
#                 Producto Escalabilidad     Coste Seguridad Nivel de uso  \
# 0                Node.js          Alta    Gratis     Media     Muy Alto
# 1                 Django          Alta    Gratis      Alta         Alto
# 2          Ruby on Rails         Media    Gratis     Media        Medio
# 3                Laravel          Alta    Gratis      Alta         Alto
# 4            Spring Boot          Alta    Gratis  Muy Alta         Alto
# 5             Express.js          Alta    Gratis     Media     Muy Alto
# 6                FastAPI          Alta    Gratis      Alta        Medio
# 7                  Flask         Media    Gratis     Media        Medio
# 8                 NestJS          Alta    Gratis      Alta        Medio
# 9                 Koa.js         Media    Gratis     Media         Bajo
# 10               Hapi.js         Media    Gratis      Alta         Bajo
# 11                Meteor         Media    Gratis     Media         Bajo
# ...

# %%
print(df_backend.columns)
# Out:
# Index(['Producto', 'Escalabilidad', 'Coste', 'Seguridad', 'Nivel de uso',
#        'Tipo', 'Lenguaje base', 'Uso principal', 'Dificultad inicial',
#        'Crecimiento de complejidad', 'Arquitectura',
#        'Soporte para concurrencia', 'Tiempo de respuesta',
#        'Ecosistema de integraciones', 'Soporte para WebSockets',
#        'Capacidad de procesamiento en paralelo'],
#       dtype='object')

# %%
df_database.head(25)
# Out:
#         Herramienta      Modelo de Datos ACID Compliance  \
# 0        PostgreSQL     Relacional (SQL)              Sí
# 1             MySQL     Relacional (SQL)              Sí
# 2           MongoDB    Documento (NoSQL)              No
# 3         Cassandra  Clave-Valor (NoSQL)              No
# 4         Oracle DB     Relacional (SQL)              Sí
# 5             Redis  Clave-Valor (NoSQL)              No
# 6             Neo4j        Grafo (NoSQL)              Sí
# 7      Apache HBase      Columna (NoSQL)              No
# 8            SQLite     Relacional (SQL)              Sí
# 9     Amazon Aurora     Relacional (SQL)              Sí
# 10      CockroachDB     Relacional (SQL)              Sí
# 11        RethinkDB    Documento (NoSQL)              No
# 12         ArangoDB  Multi-model (NoSQL)              Sí
# 13          MariaDB     Relacional (SQL)              Sí
# 14      TimescaleDB    Time-series (SQL)              Sí
# ...

# %%
print(df_database.columns)
# Out:
# Index(['Herramienta', 'Modelo de Datos', 'ACID Compliance',
#        'Capacidad de Replicación', 'Soporte para Big Data',
#        'Facilidad de Consultas (1-10)', 'Latencia de Lectura/Escritura',
#        'SQL/NoSQL', 'Distribuida/Centralizada', 'Escalabilidad', 'Coste',
#        'Seguridad', 'Nivel de Uso'],
#       dtype='object')

# %%
df_auth.head(25)
# Out:
#                                           Herramienta Tipo de Autenticación  \
# 0                                              OAuth2                 OAuth
# 1                                               Auth0             OAuth/MFA
# 2                                                Okta             OAuth/MFA
# 3                             Firebase Authentication  Contraseña/OAuth/MFA
# 4                                            OneLogin             OAuth/MFA
# 5                                       Cognito (AWS)             OAuth/MFA
# 6                                        Duo Security        Contraseña/MFA
# 7                                            Keycloak             OAuth/MFA
# 8                                        PingIdentity             OAuth/MFA
# 9                                           Bitwarden            Contraseña
# 10                                           LastPass        Contraseña/MFA
# ...

# %%
print(df_auth.columns)
# Out:
# Index(['Herramienta', 'Tipo de Autenticación', 'Soporte para MFA',
#        'Integración con Proveedores de Identidad', 'Cifrado de Datos',
#        'Cumplimiento de Normativas de Seguridad', 'Autorización Granular',
#        'Prevención de Ataques Comunes', 'Soporte para Gestión de Contraseñas',
#        'Escalabilidad', 'Coste', 'Seguridad', 'Nivel de Uso'],
#       dtype='object')

# %%
df_ecommerce.head(25)
# Out:
#          Herramienta                         Métodos de Pago Soportados  \
# 0             Stripe  Tarjetas de Crédito, PayPal, Bitcoin, Transfer...
# 1             PayPal                        Tarjetas de Crédito, PayPal
# 2             Square         Tarjetas de Crédito, Apple Pay, Google Pay
# 3           Razorpay            Tarjetas de Crédito, PayPal, Google Pay
# 4              Adyen  Tarjetas de Crédito, PayPal, Transferencias Ba...
# 5          Braintree                 Tarjetas de Crédito, PayPal, Venmo
# 6           Worldpay  Tarjetas de Crédito, PayPal, Transferencias Ba...
# 7             Klarna                   Transferencias Bancarias, PayPal
# 8   Shopify Payments                       Tarjetas de Crédito, Shopify
# 9           Payoneer      Tarjetas de Crédito, Transferencias Bancarias
# 10         2Checkout                        Tarjetas de Crédito, PayPal
# 11             WePay                        Tarjetas de Crédito, PayPal
# ...

# %%
print(df_ecommerce.columns)
# Out:
# Index(['Herramienta', 'Métodos de Pago Soportados', 'Soporte para E-commerce',
#        'Soporte para Suscripciones', 'Soporte para Pagos Internacionales',
#        'Soporte para Fraude y Prevención', 'Cargos por Transacción',
#        'Escalabilidad', 'Coste', 'Seguridad', 'Nivel de Uso'],
#       dtype='object')

# %%
df_cloudhosting.head(25)
# Out:
#              Proveedor Tipo de Servicio Soporte para Contenedores  \
# 0                  AWS             IaaS                        Sí
# 1         Google Cloud             IaaS                        Sí
# 2      Microsoft Azure             IaaS                        Sí
# 3               Heroku             PaaS                        Sí
# 4         DigitalOcean             IaaS                        Sí
# 5               Linode             IaaS                        Sí
# 6            IBM Cloud             IaaS                        Sí
# 7        Alibaba Cloud             IaaS                        Sí
# 8            OVH Cloud             IaaS                        Sí
# 9                Vultr             IaaS                        Sí
# 10  Cloudflare Workers             SaaS                        No
# 11             Netlify             PaaS                        No
# 12              Vercel             PaaS                        No
# ...

# %%
print(df_cloudhosting.columns)
# Out:
# Index(['Proveedor', 'Tipo de Servicio', 'Soporte para Contenedores',
#        'Autoescalado', 'Disponibilidad (SLA)', 'Regiones Disponibles',
#        'Escalabilidad', 'Coste', 'Seguridad', 'Nivel de Uso'],
#       dtype='object')

# %%
df_cdci_devops.head(25)
# Out:
#                  Nombre          Tipo de herramienta  \
# 0               Jenkins                        CI/CD
# 1        GitHub Actions                        CI/CD
# 2          GitLab CI/CD                        CI/CD
# 3              CircleCI                        CI/CD
# 4             Travis CI                        CI/CD
# 5   Bitbucket Pipelines                        CI/CD
# 6          Azure DevOps                        CI/CD
# 7      AWS CodePipeline                        CI/CD
# 8    Google Cloud Build                        CI/CD
# 9                ArgoCD                 Orquestación
# 10            Spinnaker                 Orquestación
# 11               Tekton                        CI/CD
# 12             Drone CI                        CI/CD
# 13             TeamCity                        CI/CD
# 14              Ansible               Automatización
# 15            Terraform  Infraestructura como Código
# 16               Pulumi  Infraestructura como Código
# ...

# %%
print(df_cdci_devops.columns)
# Out:
# Index(['Nombre', 'Tipo de herramienta', 'Soporte para Contenedores',
#        'Integración con Proveedores Cloud', 'Facilidad de Configuración',
#        'Escalado Automático', 'Escalabilidad', 'Coste', 'Seguridad',
#        'Nivel de Uso'],
#       dtype='object')

# %%
df_message.head(25)
# Out:
#                       Nombre           Tipo de Comunicación Latencia  \
# 0                     Twilio               Mensajería, VoIP     Baja
# 1                   SendGrid                     Mensajería     Baja
# 2                   Postmark                     Mensajería     Baja
# 3                     Pusher                     WebSockets     Baja
# 4                       Ably                     WebSockets     Baja
# 5                  Socket.io                     WebSockets     Baja
# 6   Firebase Cloud Messaging             Push Notifications     Baja
# 7                  OneSignal             Push Notifications     Baja
# 8                 Amazon SNS             Push Notifications     Baja
# 9                 Amazon SQS                     Mensajería     Baja
# 10         Azure Service Bus                     Mensajería     Baja
# 11            Google Pub/Sub                     Mensajería     Baja
# 12                     Kafka                      Streaming     Baja
# ...

# %%
print(df_message.columns)
# Out:
# Index(['Nombre', 'Tipo de Comunicación', 'Latencia',
#        'Soporte para Encriptación', 'Integración con Proveedores Cloud',
#        'Facilidad de Integración', 'Escalabilidad', 'Coste', 'Seguridad',
#        'Nivel de Uso'],
#       dtype='object')

# %%
df_search_engine.head(25)
# Out:
#                        Nombre                   Tipo de Motor  \
# 0               Elasticsearch  Búsqueda Full-Text, Indexación
# 1                        Solr  Búsqueda Full-Text, Indexación
# 2                     Algolia              Búsqueda Full-Text
# 3                 MeiliSearch              Búsqueda Full-Text
# 4                   Typesense              Búsqueda Full-Text
# 5                      Whoosh              Búsqueda Full-Text
# 6                      Sphinx              Búsqueda Full-Text
# 7           Amazon OpenSearch  Búsqueda Full-Text, Indexación
# 8         Google Cloud Search              Búsqueda Full-Text
# 9      Azure Cognitive Search  Búsqueda Full-Text, Indexación
# 10                   Pinecone                       Vectorial
# 11                   Weaviate                       Vectorial
# 12                      Vespa                Vectorial, Mixto
# 13                     Milvus                       Vectorial
# ...

# %%
print(df_search_engine.columns)
# Out:
# Index(['Nombre', 'Tipo de Motor', 'Soporte para Machine Learning',
#        'Capacidad de Indexación', 'Tiempo de Respuesta',
#        'Facilidad de Integración', 'Escalabilidad', 'Coste', 'Seguridad',
#        'Nivel de Uso'],
#       dtype='object')

# %%
df_media_storage.head(25)
# Out:
#                  Herramienta Escalabilidad   Coste Seguridad Nivel de uso  \
# 0                  Amazon S3          Alta   Medio      Alta         Alta
# 1       Google Cloud Storage          Alta   Medio      Alta         Alta
# 2         Azure Blob Storage          Alta   Medio      Alta         Alta
# 3                    Dropbox         Media   Medio     Media         Alta
# 4                        Box         Media   Medio     Media        Media
# 5             Cloudflare CDN          Alta    Bajo      Alta         Alta
# 6                 Akamai CDN          Alta    Alto      Alta         Alta
# 7                 Fastly CDN          Alta   Medio      Alta         Alta
# 8               Backblaze B2         Media    Bajo     Media        Media
# 9                     Wasabi          Alta    Bajo      Alta        Media
# 10       DigitalOcean Spaces         Media   Medio     Media        Media
# 11  IBM Cloud Object Storage          Alta   Medio      Alta        Media
# ...

# %%
print(df_media_storage.columns)
# Out:
# Index(['Herramienta', 'Escalabilidad', 'Coste', 'Seguridad', 'Nivel de uso',
#        'Tipo de Almacenamiento', 'Soporte para Streaming',
#        'Latencia de Acceso', 'Capacidad de Retención',
#        'Facilidad de Integración'],
#       dtype='object')
